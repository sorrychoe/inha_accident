# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

plt.figure(figsize = (14,14))

news_df = pd.read_excel("./inha_3month.xlsx", engine = 'openpyxl')

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import Normalizer

text = news_df['키워드']


pipeline = Pipeline([
    ('vect', CountVectorizer()),
    ('tfidf', TfidfTransformer()),
])        
vec = pipeline.fit_transform(text).toarray()

nor = Normalizer()
norvec = nor.fit_transform(vec)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

vzr = KElbowVisualizer(KMeans(), k=(2, 20))
vzr.fit(norvec)
vzr.poof()
# Out:
# <AxesSubplot: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
a = 12
b = a*2
c = b**a

# %%
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.cluster import KMeans

kmeans= KMeans(n_clusters=clu, max_iter=ite, random_state=10) 
visualizer = SilhouetteVisualizer(kmeans, colors='yellowbrick')

# %%
visualizer.fit(norvec)
visualizer.show()
# Out:
# <AxesSubplot: title={'center': 'Silhouette Plot of KMeans Clustering for 658 Samples in 10 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>
